# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../..')

# %%
model_id = 1
is_hitter = True

# %%
from Model.Evaluation.EvalFoldSweep import EvalFoldSweep

acc, repeat = EvalFoldSweep(model_id, is_hitter)

# %%
from Model.Evaluation.PlotFoldSweep import PlotFoldSweep

PlotFoldSweep(acc, is_hitter)

# %%
from Model.Evaluation.PlotRepeatabilityScatterGrid import *

PlotRepeatabilityScatterGrid(repeat, log_scale=True)

# %%
PlotRepeatabilityScatterGrid(repeat, log_scale=False)
