# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../..')

# %%
model_id = 1
is_hitter = True

# %%
from Model.Evaluation.EvalFoldSweep import Eval_FoldSweep

t = Eval_FoldSweep(model_id, is_hitter)

# %%
from Model.Evaluation.EvalFoldEnsemble import EvalFoldEnsemble

efe = EvalFoldEnsemble(model_id, is_hitter)
print(efe)

# %%
1 - (56768.21875 * 3) / 171914.859375

# %%
0.0025 / .2855

# %%
1 - (589.9141845703125 / 705.4555053710938)

# %%
120/710

# %%
from Model.Evaluation.PlotFoldSweep import PlotFoldSweep

PlotFoldSweep(t, is_hitter)
