# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../..")

# %%
from Model.Constants import db, model_db

# %%
import Model.DraftPickSlot.DataPrep as DataPrep

X, Y, players = DataPrep.load_dataset(db, model_db)

# %%
(X_train, Y_train), (X_test, Y_test) = DataPrep.train_test_split(X, Y)

# %%
X_train, mean, std = DataPrep.normalize(X_train)
X_test = DataPrep.apply_normalize(X_test, mean, std)

# %%
from Model.DraftPickSlot.DraftModel import WarNet

model = WarNet()

# %%
import Model.DraftPickSlot.Train as Train

Train.train(model, X_train, Y_train, X_test, Y_test, should_output=True, num_epochs=100)

# %%
test_loss, _ = Train.evaluate(model, X_test, Y_test)
print(test_loss)
